# %%
import pandas as pd
import json

race_df = pd.read_parquet('./datasets/race/test-00000-of-00001.parquet')
# race_m_df = pd.read_parquet('./datasets/race-m/test-00000-of-00001.parquet')

# Load DREAM dataset (both test and dev)
with open('./datasets/dream/test.json', 'r', encoding='utf-8') as f:
    dream_test_data = json.load(f)

with open('./datasets/dream/dev.json', 'r', encoding='utf-8') as f:
    dream_dev_data = json.load(f)

# Combine both DREAM datasets
dream_data = dream_test_data + dream_dev_data

# Load ReClor validation dataset
with open('./datasets/reclor/val.json', 'r', encoding='utf-8') as f:
    reclor_data = json.load(f)

print(f"DREAM test samples: {len(dream_test_data)}")
print(f"DREAM dev samples: {len(dream_dev_data)}")
print(f"Total DREAM samples: {len(dream_data)}")
print(f"ReClor validation samples: {len(reclor_data)}")
# Out:
# DREAM test samples: 1287
# DREAM dev samples: 1288
# Total DREAM samples: 2575
# ReClor validation samples: 500

# %%
race_df.head()
# Out:
#       example_id                                            article answer  \
# 0  high19432.txt  The rain had continued for a week and the floo...      C
# 1  high19432.txt  The rain had continued for a week and the floo...      D
# 2  high19432.txt  The rain had continued for a week and the floo...      A
# 3   high6268.txt  There is probably no field of human activity i...      B
# 4   high6268.txt  There is probably no field of human activity i...      B
#
#                                             question  \
# 0     What did Nancy try to do before she fell over?
# 1  The following are true according to the passag...
# 2  What did the local people do to help those in ...
# 3                   The passage tells us that   _  .
# 4   Traditionally,people usually thought that   _  .
#
#                                              options
# 0  [Measure the depth of the river, Look for a fa...
# 1  [It took Lizzie and Nancy about 20 minutes to ...
# 2  [They put up shelter for them in a school., Th...
# 3  [our values and lifestyles are in no field of ...
# 4  [men cared very much for clothes, women were c...

# %%
# race_m_df.head()
race_df.head()
# Out:
#       example_id                                            article answer  \
# 0  high19432.txt  The rain had continued for a week and the floo...      C
# 1  high19432.txt  The rain had continued for a week and the floo...      D
# 2  high19432.txt  The rain had continued for a week and the floo...      A
# 3   high6268.txt  There is probably no field of human activity i...      B
# 4   high6268.txt  There is probably no field of human activity i...      B
#
#                                             question  \
# 0     What did Nancy try to do before she fell over?
# 1  The following are true according to the passag...
# 2  What did the local people do to help those in ...
# 3                   The passage tells us that   _  .
# 4   Traditionally,people usually thought that   _  .
#
#                                              options
# 0  [Measure the depth of the river, Look for a fa...
# 1  [It took Lizzie and Nancy about 20 minutes to ...
# 2  [They put up shelter for them in a school., Th...
# 3  [our values and lifestyles are in no field of ...
# 4  [men cared very much for clothes, women were c...

# %%
import random

# Set seed for reproducibility (not needed anymore but keeping for consistency)
random.seed(42)

# Number of samples to select from each dataset
N = 100  # You can change this value

def select_samples_by_question_count(df, source_name, n_samples):
    """
    Select n_samples with the most questions from the dataframe
    """
    # Count questions per example_id
    question_counts = df.groupby('example_id').size().reset_index(name='question_count')
    
    # Sort by question count (descending) and get top n
    top_examples = question_counts.nlargest(n_samples, 'question_count')
    selected_ids = top_examples['example_id'].tolist()
    
    return df[df['example_id'].isin(selected_ids)], selected_ids

def select_dream_samples_by_question_count(dream_data, n_samples):
    """
    Select n_samples with the most questions from DREAM dataset
    """
    # Create list of (index, question_count) tuples
    sample_counts = [(i, len(sample[1])) for i, sample in enumerate(dream_data)]
    
    # Sort by question count (descending) and get top n
    sample_counts.sort(key=lambda x: x[1], reverse=True)
    selected_indices = [idx for idx, _ in sample_counts[:n_samples]]
    
    return [dream_data[i] for i in selected_indices], selected_indices

def select_reclor_samples(reclor_data, n_samples):
    """
    Select n_samples from ReClor dataset (only 1 question per sample)
    Just take the first n_samples since each sample has 1 question
    """
    return reclor_data[:n_samples], list(range(n_samples))

# Select samples from all datasets
race_samples, race_ids = select_samples_by_question_count(race_df, 'race', N)
dream_samples, dream_indices = select_dream_samples_by_question_count(dream_data, N)
reclor_samples, reclor_indices = select_reclor_samples(reclor_data, N)

print(f"Selected {len(race_ids)} unique articles from RACE (with most questions)")
print(f"Selected {len(dream_indices)} samples from DREAM (with most questions)")
print(f"Selected {len(reclor_indices)} samples from ReClor")
# Out:
# Selected 100 unique articles from RACE (with most questions)
# Selected 100 samples from DREAM (with most questions)
# Selected 100 samples from ReClor

# %%
def transform_to_format(df, source_name, start_id=1):
    """
    Transform dataframe to the desired format, grouping by example_id
    Convert ABCD to 0123 in correct field
    """
    results = []
    current_id = start_id
    
    # Mapping for converting ABCD to 0123
    answer_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3}
    
    # Group by example_id
    grouped = df.groupby('example_id')
    
    for example_id, group in grouped:
        # Get the article content (same for all rows in group)
        content = group.iloc[0]['article']
        
        # Create questions list
        questions = []
        for _, row in group.iterrows():
            questions.append({
                'content': row['question'],
                'correct': answer_map.get(row['answer'], row['answer']),  # Convert ABCD to 0123
                'options': row['options'].tolist() if hasattr(row['options'], 'tolist') else list(row['options'])
            })
        
        # Create the result object
        result = {
            'id': current_id,
            'source': source_name,
            'content': content,
            'questions': questions
        }
        
        results.append(result)
        current_id += 1
    
    return results, current_id

def transform_dream_to_format(dream_samples, source_name, start_id=1):
    """
    Transform DREAM dataset to the desired format
    DREAM format: [dialogue_lines_list, questions_list, id]
    """
    results = []
    current_id = start_id
    
    for sample in dream_samples:
        # sample[0] is the dialogue (list of strings)
        # sample[1] is the questions list
        # sample[2] is the original id
        
        dialogue_lines = sample[0]
        questions_data = sample[1]
        
        # Join dialogue lines to create content
        content = '\n'.join(dialogue_lines)
        
        # Create questions list
        questions = []
        for q in questions_data:
            # Find the correct answer index in the choice list
            correct_index = q['choice'].index(q['answer'])
            
            questions.append({
                'content': q['question'],
                'correct': correct_index,
                'options': q['choice']
            })
        
        # Create the result object
        result = {
            'id': current_id,
            'source': source_name,
            'content': content,
            'questions': questions
        }
        
        results.append(result)
        current_id += 1
    
    return results, current_id

def transform_reclor_to_format(reclor_samples, source_name, start_id=1):
    """
    Transform ReClor dataset to the desired format
    ReClor format: {context, question, answers, label, id_string}
    Each sample has only 1 question
    """
    results = []
    current_id = start_id
    
    for sample in reclor_samples:
        # Create questions list with single question
        questions = [{
            'content': sample['question'],
            'correct': sample['label'],  # Already in 0-3 format
            'options': sample['answers']
        }]
        
        # Create the result object
        result = {
            'id': current_id,
            'source': source_name,
            'content': sample['context'],
            'questions': questions
        }
        
        results.append(result)
        current_id += 1
    
    return results, current_id

# Transform all datasets
race_results, next_id = transform_to_format(race_samples, 'race', start_id=1)
# race_m_results, next_id = transform_to_format(race_m_samples, 'race-m', start_id=next_id)
dream_results, next_id = transform_dream_to_format(dream_samples, 'dream', start_id=next_id)
reclor_results, next_id = transform_reclor_to_format(reclor_samples, 'reclor', start_id=next_id)

# Combine all results
all_results = race_results + dream_results + reclor_results  # + race_m_results

print(f"Total samples: {len(all_results)}")
print(f"race samples: {len(race_results)}")
# print(f"RACE-M samples: {len(race_m_results)}")
print(f"DREAM samples: {len(dream_results)}")
print(f"ReClor samples: {len(reclor_results)}")
# Out:
# Total samples: 300
# race samples: 100
# DREAM samples: 100
# ReClor samples: 100

# %%
# Display a sample to verify the format
import json

print("Sample output:")
print(json.dumps(all_results[0], indent=2, ensure_ascii=False))
# Out:
# Sample output:
# {
#   "id": 1,
#   "source": "race",
#   "content": "Studies show that you may be lied to every day anywhere from 10 to 200 times. We say, \"Nice song.\" \"Honey, you don't look fat in that, no.\" But another study showed that strangers lied three times within the first 10 minutes of meeting each other. We lie more to strangers than we lie to coworkers. Men lie eight times more about themselves than they do other people. Women lie more to protect other people. If you're married, you're going to lie to your wife/ husband in one out of every 10 communications. If you're unmarried, that number drops to three. But look, if at some point you got lied to, it's because you agreed to get lied to. Truth about lying: lying's a cooperative act. Not all lies are harmful. Sometimes we're willing to lie for the sake of social dignity  , maybe to keep a private secret.\nLying is complex. It's woven into the fabric of our daily and business lives. We're deeply disturbed by the truth. We explain it, sometimes for very good reasons, other times just because we don't understand the gaps between ideals and realities in our lives. We're against lying, but secretly we're for it in ways that our society has practiced for centuries and centuries. It's as old as breathing. It's part of our culture and history. Think the stories from Dante, Shakespeare, the Bible, News of the World.\nLying has great value to the evolution of human being. Researchers have long known that the more intelligent the species, the more likely it is to lie. We human like to become leaders. It starts really early. How early? Well, babies will pretend to cry, pause, wait to see who's coming and then go right back to crying. One-year-olds learn hiding truth. Two-year-olds bluff  . Five-year-olds lie outright and try to control via flattery  . Nine-year-olds, masters of covering up. By the time you enter college, you're going to lie to your mom in one out of every five interactions. By the time we enter this work world to be breadwinners, we've entered a world that is just full of fake digital friends, business media, identity thieves, world-class cheats, ----in short, a post-truth society.\nWhat do you do? Well there are steps we can take to guide our way through the bushes. Trained lie spotters get to the truth 90% of the time. The rest of us, we're only 54% accurate. Why is it so easy to learn? There are clever liars and stupid liars. There're no real original liars. We all make the same mistakes. We all use the same techniques.",
#   "questions": [
#     {
#       "content": "From Para.1 we learn that lying is very   _  .",
#       "correct": 3,
#       "options": [
#         "harmful",
#         "easy",
#         "interesting",
#         "common"
#       ]
#     },
#     {
#       "content": "According to the passage, a lie works when   _  .",
#       "correct": 2,
#       "options": [
#         "the liar's words are sweet enough",
#         "it is given to a complete stranger",
#         "someone gives the liar cooperation",
#         "we are willing to lie for the dignity"
#       ]
#     },
#     {
#       "content": "Lying is complex because   _  .",
#       "correct": 1,
#       "options": [
#         "it is practiced by clever ones",
#         "people are for it as well as against it",
#         "ancient stories are full of lies",
#         "it is the whole part of great culture"
#       ]
#     },
#     {
#       "content": "The examples of kids lying in the passage show   _  .",
#       "correct": 0,
#       "options": [
#         "lying is a sign of intelligent development",
#         "lying is good for children's growing up",
#         "at what age children begin to tell lies",
#         "9-year-old children are masters of lying"
#       ]
#     },
#     {
#       "content": "What will the writer most likely talk about if he continues the passage?",
#       "correct": 3,
#       "options": [
#         "How to become clever liars.",
#         "How to avoid stupid lies.",
#         "How to get through the bushes.",
#         "How to tell truth from lies."
#       ]
#     }
#   ]
# }

# %%
# Display samples from each source to verify the format
print("\nSample DREAM output:")
for result in all_results:
    if result['source'] == 'dream':
        print(json.dumps(result, indent=2, ensure_ascii=False))
        break

print("\nSample ReClor output:")
for result in all_results:
    if result['source'] == 'reclor':
        print(json.dumps(result, indent=2, ensure_ascii=False))
        break
# Out:
# Sample DREAM output:
# {
#   "id": 101,
#   "source": "dream",
#   "content": "Man: I'm home!\nWoman: Hi sweetie. Welcome home. Are you ready to eat?\nMan: Well, ... uh ...\nWoman: Uh, we're having fish and seasoned rice and carrots for the main course.\nMan: Really? Um .. Yeah.\nWoman: What? What?\nMan: Oh, that sounds great.\nWoman: Are you sure?\nMan: Sure.\nWoman: Hm. Well, before that, I have a delicious seafood salad with shrimp.\nMan: Oh.\nWoman: And, for desert, I made apple pie.\nMan: Oooh.\nWoman: Honey. It took me three hours to make.\nMan: Oh ... well ... yeah ... um ... yeah.\nWoman: Hmm. What's wrong? Don't you like ... don't you like what I made?\nMan: Well, to be honest, I just had a hamburger, fries, and a chocolate shake.\nWoman: You're kidding. Really?\nMan: Yeah. I'm sorry. I didn't know that you were making ...\nWoman: Honey. I told you this morning that I was making you something nice.\nMan: Yeah, but I forgot. You ... you know how work is. Wait, wow, WAIT!! What are you doing? Why are you putting the food in my shoes?\nWoman: So you can enjoy it as you walk to work tomorrow.\nMan: Ah!",
#   "questions": [
#     {
#       "content": "What did the woman make for dinner?",
#       "correct": 2,
#       "options": [
#         "steak, potatoes, and peas",
#         "chicken, bread, and corn",
#         "fish, rice, and carrots"
#       ]
#     },
#     {
#       "content": "She also made a salad with __________.",
#       "correct": 0,
#       "options": [
#         "shrimp",
#         "bacon",
#         "tomatoes"
#       ]
#     },
#     {
#       "content": "She is going to serve _________ for dessert.",
#       "correct": 1,
#       "options": [
#         "ice cream",
#         "apple pie",
#         "cake"
#       ]
#     },
#     {
#       "content": "It took her _________ hours to make the meal.",
#       "correct": 1,
#       "options": [
#         "two",
#         "three",
#         "four"
#       ]
#     },
#     {
#       "content": "Why isn't the man hungry?",
#       "correct": 0,
#       "options": [
#         "He ate something before.",
#         "He is feeling a little sick.",
#         "He doesn't like what she made."
#       ]
#     },
#     {
#       "content": "How does the woman feel?",
#       "correct": 0,
#       "options": [
#         "frustrated",
#         "confused",
#         "worried"
#       ]
#     },
#     {
#       "content": "Where does the woman put the food at the end of the conversation?",
#       "correct": 2,
#       "options": [
#         "in the refrigerator",
#         "in the garbage",
#         "in some shoes"
#       ]
#     }
#   ]
# }
#
# Sample ReClor output:
# {
#   "id": 201,
#   "source": "reclor",
#   "content": "In a business whose owners and employees all belong to one family, the employees can be paid exceptionally low wages. Hence, general operating expenses are much lower than they would be for other business ventures, making profits higher. So a family business is a family' s surest road to financial prosperity.",
#   "questions": [
#     {
#       "content": "The reasoning in the argument is flawed because the argument",
#       "correct": 0,
#       "options": [
#         "ignores the fact that in a family business, paying family members low wages may itself reduce the family's prosperity",
#         "presumes, without providing justification, that family members are willing to work for low wages in a family business because they believe that doing so promotes the family's prosperity",
#         "ignores the fact that businesses that achieve high levels of customer satisfaction are often profitable even if they pay high wages",
#         "presumes, without providing justification, that only businesses with low general operating expenses can succeed"
#       ]
#     }
#   ]
# }

# %%
# Summary statistics
print("\n=== Summary Statistics ===")
for result in all_results:
    print(f"ID: {result['id']}, Source: {result['source']}, Questions: {len(result['questions'])}, Content length: {len(result['content'])} chars")
# Out:
# === Summary Statistics ===
# ID: 1, Source: race, Questions: 5, Content length: 2462 chars
# ID: 2, Source: race, Questions: 6, Content length: 3408 chars
# ID: 3, Source: race, Questions: 5, Content length: 1168 chars
# ID: 4, Source: race, Questions: 6, Content length: 4244 chars
# ID: 5, Source: race, Questions: 5, Content length: 1664 chars
# ID: 6, Source: race, Questions: 5, Content length: 2101 chars
# ID: 7, Source: race, Questions: 5, Content length: 1696 chars
# ID: 8, Source: race, Questions: 5, Content length: 1548 chars
# ID: 9, Source: race, Questions: 5, Content length: 1656 chars
# ID: 10, Source: race, Questions: 5, Content length: 1490 chars
# ID: 11, Source: race, Questions: 5, Content length: 4164 chars
# ID: 12, Source: race, Questions: 5, Content length: 1052 chars
# ID: 13, Source: race, Questions: 5, Content length: 2375 chars
# ID: 14, Source: race, Questions: 5, Content length: 2140 chars
# ID: 15, Source: race, Questions: 5, Content length: 1468 chars
# ID: 16, Source: race, Questions: 5, Content length: 2392 chars
# ID: 17, Source: race, Questions: 5, Content length: 1440 chars
# ID: 18, Source: race, Questions: 5, Content length: 1158 chars
# ID: 19, Source: race, Questions: 5, Content length: 1862 chars
# ID: 20, Source: race, Questions: 6, Content length: 3611 chars
# ID: 21, Source: race, Questions: 5, Content length: 1140 chars
# ID: 22, Source: race, Questions: 5, Content length: 1765 chars
# ID: 23, Source: race, Questions: 5, Content length: 1228 chars
# ID: 24, Source: race, Questions: 5, Content length: 712 chars
# ID: 25, Source: race, Questions: 5, Content length: 1796 chars
# ID: 26, Source: race, Questions: 5, Content length: 1501 chars
# ID: 27, Source: race, Questions: 5, Content length: 2979 chars
# ID: 28, Source: race, Questions: 5, Content length: 1287 chars
# ID: 29, Source: race, Questions: 5, Content length: 2162 chars
# ID: 30, Source: race, Questions: 5, Content length: 1614 chars
# ID: 31, Source: race, Questions: 5, Content length: 2216 chars
# ID: 32, Source: race, Questions: 5, Content length: 2371 chars
# ID: 33, Source: race, Questions: 5, Content length: 1358 chars
# ID: 34, Source: race, Questions: 5, Content length: 672 chars
# ID: 35, Source: race, Questions: 5, Content length: 1537 chars
# ID: 36, Source: race, Questions: 5, Content length: 1574 chars
# ID: 37, Source: race, Questions: 5, Content length: 1311 chars
# ID: 38, Source: race, Questions: 5, Content length: 2041 chars
# ID: 39, Source: race, Questions: 5, Content length: 1697 chars
# ID: 40, Source: race, Questions: 5, Content length: 1108 chars
# ID: 41, Source: race, Questions: 5, Content length: 1785 chars
# ID: 42, Source: race, Questions: 5, Content length: 1712 chars
# ID: 43, Source: race, Questions: 5, Content length: 2047 chars
# ID: 44, Source: race, Questions: 5, Content length: 1921 chars
# ID: 45, Source: race, Questions: 5, Content length: 1913 chars
# ID: 46, Source: race, Questions: 5, Content length: 3294 chars
# ID: 47, Source: race, Questions: 5, Content length: 1370 chars
# ID: 48, Source: race, Questions: 5, Content length: 918 chars
# ID: 49, Source: race, Questions: 5, Content length: 3392 chars
# ID: 50, Source: race, Questions: 5, Content length: 2184 chars
# ID: 51, Source: race, Questions: 5, Content length: 2447 chars
# ID: 52, Source: race, Questions: 5, Content length: 1045 chars
# ID: 53, Source: race, Questions: 5, Content length: 917 chars
# ID: 54, Source: race, Questions: 5, Content length: 768 chars
# ID: 55, Source: race, Questions: 5, Content length: 2523 chars
# ID: 56, Source: race, Questions: 5, Content length: 2127 chars
# ID: 57, Source: race, Questions: 5, Content length: 1171 chars
# ID: 58, Source: race, Questions: 5, Content length: 1769 chars
# ID: 59, Source: race, Questions: 5, Content length: 1566 chars
# ID: 60, Source: race, Questions: 5, Content length: 1420 chars
# ID: 61, Source: race, Questions: 5, Content length: 2331 chars
# ID: 62, Source: race, Questions: 5, Content length: 2032 chars
# ID: 63, Source: race, Questions: 5, Content length: 1681 chars
# ID: 64, Source: race, Questions: 5, Content length: 1782 chars
# ID: 65, Source: race, Questions: 5, Content length: 1184 chars
# ID: 66, Source: race, Questions: 5, Content length: 1319 chars
# ID: 67, Source: race, Questions: 5, Content length: 2157 chars
# ID: 68, Source: race, Questions: 5, Content length: 1075 chars
# ID: 69, Source: race, Questions: 5, Content length: 1584 chars
# ID: 70, Source: race, Questions: 5, Content length: 1329 chars
# ID: 71, Source: race, Questions: 5, Content length: 1631 chars
# ID: 72, Source: race, Questions: 5, Content length: 1752 chars
# ID: 73, Source: race, Questions: 5, Content length: 1374 chars
# ID: 74, Source: race, Questions: 5, Content length: 1533 chars
# ID: 75, Source: race, Questions: 5, Content length: 4496 chars
# ID: 76, Source: race, Questions: 5, Content length: 2201 chars
# ID: 77, Source: race, Questions: 5, Content length: 1686 chars
# ID: 78, Source: race, Questions: 5, Content length: 1564 chars
# ID: 79, Source: race, Questions: 5, Content length: 1740 chars
# ID: 80, Source: race, Questions: 6, Content length: 3684 chars
# ID: 81, Source: race, Questions: 5, Content length: 1914 chars
# ID: 82, Source: race, Questions: 5, Content length: 4192 chars
# ID: 83, Source: race, Questions: 5, Content length: 1962 chars
# ID: 84, Source: race, Questions: 5, Content length: 1812 chars
# ID: 85, Source: race, Questions: 5, Content length: 950 chars
# ID: 86, Source: race, Questions: 5, Content length: 1630 chars
# ID: 87, Source: race, Questions: 5, Content length: 1540 chars
# ID: 88, Source: race, Questions: 5, Content length: 849 chars
# ID: 89, Source: race, Questions: 5, Content length: 1927 chars
# ID: 90, Source: race, Questions: 5, Content length: 2123 chars
# ID: 91, Source: race, Questions: 5, Content length: 1450 chars
# ID: 92, Source: race, Questions: 5, Content length: 2234 chars
# ID: 93, Source: race, Questions: 5, Content length: 1630 chars
# ID: 94, Source: race, Questions: 5, Content length: 2121 chars
# ID: 95, Source: race, Questions: 5, Content length: 2040 chars
# ID: 96, Source: race, Questions: 5, Content length: 735 chars
# ID: 97, Source: race, Questions: 5, Content length: 1265 chars
# ID: 98, Source: race, Questions: 5, Content length: 2211 chars
# ID: 99, Source: race, Questions: 5, Content length: 1245 chars
# ID: 100, Source: race, Questions: 5, Content length: 1543 chars
# ID: 101, Source: dream, Questions: 7, Content length: 1023 chars
# ID: 102, Source: dream, Questions: 7, Content length: 2236 chars
# ID: 103, Source: dream, Questions: 7, Content length: 1255 chars
# ID: 104, Source: dream, Questions: 6, Content length: 2541 chars
# ID: 105, Source: dream, Questions: 6, Content length: 2007 chars
# ID: 106, Source: dream, Questions: 6, Content length: 1303 chars
# ID: 107, Source: dream, Questions: 5, Content length: 1227 chars
# ID: 108, Source: dream, Questions: 5, Content length: 2917 chars
# ID: 109, Source: dream, Questions: 5, Content length: 3477 chars
# ID: 110, Source: dream, Questions: 5, Content length: 1180 chars
# ID: 111, Source: dream, Questions: 5, Content length: 1250 chars
# ID: 112, Source: dream, Questions: 5, Content length: 807 chars
# ID: 113, Source: dream, Questions: 5, Content length: 1305 chars
# ID: 114, Source: dream, Questions: 5, Content length: 950 chars
# ID: 115, Source: dream, Questions: 5, Content length: 912 chars
# ID: 116, Source: dream, Questions: 5, Content length: 4230 chars
# ID: 117, Source: dream, Questions: 5, Content length: 1825 chars
# ID: 118, Source: dream, Questions: 5, Content length: 1750 chars
# ID: 119, Source: dream, Questions: 5, Content length: 2107 chars
# ID: 120, Source: dream, Questions: 5, Content length: 959 chars
# ID: 121, Source: dream, Questions: 5, Content length: 2011 chars
# ID: 122, Source: dream, Questions: 5, Content length: 1235 chars
# ID: 123, Source: dream, Questions: 5, Content length: 1105 chars
# ID: 124, Source: dream, Questions: 5, Content length: 2202 chars
# ID: 125, Source: dream, Questions: 5, Content length: 1904 chars
# ID: 126, Source: dream, Questions: 5, Content length: 3876 chars
# ID: 127, Source: dream, Questions: 5, Content length: 1520 chars
# ID: 128, Source: dream, Questions: 5, Content length: 1601 chars
# ID: 129, Source: dream, Questions: 5, Content length: 1383 chars
# ID: 130, Source: dream, Questions: 5, Content length: 2229 chars
# ID: 131, Source: dream, Questions: 5, Content length: 2427 chars
# ID: 132, Source: dream, Questions: 5, Content length: 1353 chars
# ID: 133, Source: dream, Questions: 5, Content length: 1668 chars
# ID: 134, Source: dream, Questions: 5, Content length: 553 chars
# ID: 135, Source: dream, Questions: 5, Content length: 1707 chars
# ID: 136, Source: dream, Questions: 5, Content length: 1476 chars
# ID: 137, Source: dream, Questions: 5, Content length: 2287 chars
# ID: 138, Source: dream, Questions: 5, Content length: 3484 chars
# ID: 139, Source: dream, Questions: 5, Content length: 2407 chars
# ID: 140, Source: dream, Questions: 5, Content length: 1554 chars
# ID: 141, Source: dream, Questions: 5, Content length: 1584 chars
# ID: 142, Source: dream, Questions: 5, Content length: 1459 chars
# ID: 143, Source: dream, Questions: 5, Content length: 846 chars
# ID: 144, Source: dream, Questions: 5, Content length: 1801 chars
# ID: 145, Source: dream, Questions: 5, Content length: 2148 chars
# ID: 146, Source: dream, Questions: 5, Content length: 1179 chars
# ID: 147, Source: dream, Questions: 5, Content length: 3945 chars
# ID: 148, Source: dream, Questions: 5, Content length: 2206 chars
# ID: 149, Source: dream, Questions: 5, Content length: 2016 chars
# ID: 150, Source: dream, Questions: 5, Content length: 2330 chars
# ID: 151, Source: dream, Questions: 5, Content length: 3028 chars
# ID: 152, Source: dream, Questions: 5, Content length: 1453 chars
# ID: 153, Source: dream, Questions: 5, Content length: 868 chars
# ID: 154, Source: dream, Questions: 5, Content length: 2276 chars
# ID: 155, Source: dream, Questions: 5, Content length: 1337 chars
# ID: 156, Source: dream, Questions: 5, Content length: 1450 chars
# ID: 157, Source: dream, Questions: 5, Content length: 1926 chars
# ID: 158, Source: dream, Questions: 5, Content length: 2679 chars
# ID: 159, Source: dream, Questions: 5, Content length: 1549 chars
# ID: 160, Source: dream, Questions: 5, Content length: 2058 chars
# ID: 161, Source: dream, Questions: 5, Content length: 1358 chars
# ID: 162, Source: dream, Questions: 5, Content length: 1185 chars
# ID: 163, Source: dream, Questions: 5, Content length: 1114 chars
# ID: 164, Source: dream, Questions: 5, Content length: 1017 chars
# ID: 165, Source: dream, Questions: 5, Content length: 762 chars
# ID: 166, Source: dream, Questions: 5, Content length: 658 chars
# ID: 167, Source: dream, Questions: 5, Content length: 1732 chars
# ID: 168, Source: dream, Questions: 5, Content length: 1914 chars
# ID: 169, Source: dream, Questions: 5, Content length: 1320 chars
# ID: 170, Source: dream, Questions: 5, Content length: 1949 chars
# ID: 171, Source: dream, Questions: 5, Content length: 4194 chars
# ID: 172, Source: dream, Questions: 4, Content length: 669 chars
# ID: 173, Source: dream, Questions: 4, Content length: 1022 chars
# ID: 174, Source: dream, Questions: 4, Content length: 1111 chars
# ID: 175, Source: dream, Questions: 4, Content length: 697 chars
# ID: 176, Source: dream, Questions: 4, Content length: 598 chars
# ID: 177, Source: dream, Questions: 4, Content length: 1311 chars
# ID: 178, Source: dream, Questions: 4, Content length: 799 chars
# ID: 179, Source: dream, Questions: 4, Content length: 1291 chars
# ID: 180, Source: dream, Questions: 4, Content length: 1488 chars
# ID: 181, Source: dream, Questions: 4, Content length: 983 chars
# ID: 182, Source: dream, Questions: 4, Content length: 477 chars
# ID: 183, Source: dream, Questions: 4, Content length: 1490 chars
# ID: 184, Source: dream, Questions: 4, Content length: 1225 chars
# ID: 185, Source: dream, Questions: 4, Content length: 974 chars
# ID: 186, Source: dream, Questions: 4, Content length: 1139 chars
# ID: 187, Source: dream, Questions: 4, Content length: 967 chars
# ID: 188, Source: dream, Questions: 4, Content length: 1047 chars
# ID: 189, Source: dream, Questions: 4, Content length: 1075 chars
# ID: 190, Source: dream, Questions: 4, Content length: 703 chars
# ID: 191, Source: dream, Questions: 4, Content length: 1632 chars
# ID: 192, Source: dream, Questions: 4, Content length: 792 chars
# ID: 193, Source: dream, Questions: 4, Content length: 545 chars
# ID: 194, Source: dream, Questions: 4, Content length: 1234 chars
# ID: 195, Source: dream, Questions: 4, Content length: 737 chars
# ID: 196, Source: dream, Questions: 4, Content length: 1407 chars
# ID: 197, Source: dream, Questions: 4, Content length: 1529 chars
# ID: 198, Source: dream, Questions: 4, Content length: 962 chars
# ID: 199, Source: dream, Questions: 4, Content length: 682 chars
# ID: 200, Source: dream, Questions: 4, Content length: 848 chars
# ID: 201, Source: reclor, Questions: 1, Content length: 310 chars
# ID: 202, Source: reclor, Questions: 1, Content length: 348 chars
# ID: 203, Source: reclor, Questions: 1, Content length: 128 chars
# ID: 204, Source: reclor, Questions: 1, Content length: 178 chars
# ID: 205, Source: reclor, Questions: 1, Content length: 716 chars
# ID: 206, Source: reclor, Questions: 1, Content length: 428 chars
# ID: 207, Source: reclor, Questions: 1, Content length: 529 chars
# ID: 208, Source: reclor, Questions: 1, Content length: 394 chars
# ID: 209, Source: reclor, Questions: 1, Content length: 415 chars
# ID: 210, Source: reclor, Questions: 1, Content length: 546 chars
# ID: 211, Source: reclor, Questions: 1, Content length: 296 chars
# ID: 212, Source: reclor, Questions: 1, Content length: 346 chars
# ID: 213, Source: reclor, Questions: 1, Content length: 370 chars
# ID: 214, Source: reclor, Questions: 1, Content length: 400 chars
# ID: 215, Source: reclor, Questions: 1, Content length: 351 chars
# ID: 216, Source: reclor, Questions: 1, Content length: 439 chars
# ID: 217, Source: reclor, Questions: 1, Content length: 327 chars
# ID: 218, Source: reclor, Questions: 1, Content length: 347 chars
# ID: 219, Source: reclor, Questions: 1, Content length: 450 chars
# ID: 220, Source: reclor, Questions: 1, Content length: 566 chars
# ID: 221, Source: reclor, Questions: 1, Content length: 658 chars
# ID: 222, Source: reclor, Questions: 1, Content length: 282 chars
# ID: 223, Source: reclor, Questions: 1, Content length: 436 chars
# ID: 224, Source: reclor, Questions: 1, Content length: 285 chars
# ID: 225, Source: reclor, Questions: 1, Content length: 300 chars
# ID: 226, Source: reclor, Questions: 1, Content length: 407 chars
# ID: 227, Source: reclor, Questions: 1, Content length: 418 chars
# ID: 228, Source: reclor, Questions: 1, Content length: 595 chars
# ID: 229, Source: reclor, Questions: 1, Content length: 261 chars
# ID: 230, Source: reclor, Questions: 1, Content length: 541 chars
# ID: 231, Source: reclor, Questions: 1, Content length: 453 chars
# ID: 232, Source: reclor, Questions: 1, Content length: 237 chars
# ID: 233, Source: reclor, Questions: 1, Content length: 330 chars
# ID: 234, Source: reclor, Questions: 1, Content length: 393 chars
# ID: 235, Source: reclor, Questions: 1, Content length: 205 chars
# ID: 236, Source: reclor, Questions: 1, Content length: 437 chars
# ID: 237, Source: reclor, Questions: 1, Content length: 458 chars
# ID: 238, Source: reclor, Questions: 1, Content length: 201 chars
# ID: 239, Source: reclor, Questions: 1, Content length: 428 chars
# ID: 240, Source: reclor, Questions: 1, Content length: 490 chars
# ID: 241, Source: reclor, Questions: 1, Content length: 370 chars
# ID: 242, Source: reclor, Questions: 1, Content length: 220 chars
# ID: 243, Source: reclor, Questions: 1, Content length: 396 chars
# ID: 244, Source: reclor, Questions: 1, Content length: 511 chars
# ID: 245, Source: reclor, Questions: 1, Content length: 435 chars
# ID: 246, Source: reclor, Questions: 1, Content length: 661 chars
# ID: 247, Source: reclor, Questions: 1, Content length: 275 chars
# ID: 248, Source: reclor, Questions: 1, Content length: 561 chars
# ID: 249, Source: reclor, Questions: 1, Content length: 638 chars
# ID: 250, Source: reclor, Questions: 1, Content length: 396 chars
# ID: 251, Source: reclor, Questions: 1, Content length: 415 chars
# ID: 252, Source: reclor, Questions: 1, Content length: 259 chars
# ID: 253, Source: reclor, Questions: 1, Content length: 202 chars
# ID: 254, Source: reclor, Questions: 1, Content length: 655 chars
# ID: 255, Source: reclor, Questions: 1, Content length: 333 chars
# ID: 256, Source: reclor, Questions: 1, Content length: 439 chars
# ID: 257, Source: reclor, Questions: 1, Content length: 475 chars
# ID: 258, Source: reclor, Questions: 1, Content length: 300 chars
# ID: 259, Source: reclor, Questions: 1, Content length: 520 chars
# ID: 260, Source: reclor, Questions: 1, Content length: 337 chars
# ID: 261, Source: reclor, Questions: 1, Content length: 313 chars
# ID: 262, Source: reclor, Questions: 1, Content length: 480 chars
# ID: 263, Source: reclor, Questions: 1, Content length: 240 chars
# ID: 264, Source: reclor, Questions: 1, Content length: 531 chars
# ID: 265, Source: reclor, Questions: 1, Content length: 634 chars
# ID: 266, Source: reclor, Questions: 1, Content length: 623 chars
# ID: 267, Source: reclor, Questions: 1, Content length: 527 chars
# ID: 268, Source: reclor, Questions: 1, Content length: 284 chars
# ID: 269, Source: reclor, Questions: 1, Content length: 349 chars
# ID: 270, Source: reclor, Questions: 1, Content length: 504 chars
# ID: 271, Source: reclor, Questions: 1, Content length: 353 chars
# ID: 272, Source: reclor, Questions: 1, Content length: 398 chars
# ID: 273, Source: reclor, Questions: 1, Content length: 421 chars
# ID: 274, Source: reclor, Questions: 1, Content length: 420 chars
# ID: 275, Source: reclor, Questions: 1, Content length: 352 chars
# ID: 276, Source: reclor, Questions: 1, Content length: 528 chars
# ID: 277, Source: reclor, Questions: 1, Content length: 488 chars
# ID: 278, Source: reclor, Questions: 1, Content length: 436 chars
# ID: 279, Source: reclor, Questions: 1, Content length: 312 chars
# ID: 280, Source: reclor, Questions: 1, Content length: 531 chars
# ID: 281, Source: reclor, Questions: 1, Content length: 331 chars
# ID: 282, Source: reclor, Questions: 1, Content length: 325 chars
# ID: 283, Source: reclor, Questions: 1, Content length: 284 chars
# ID: 284, Source: reclor, Questions: 1, Content length: 520 chars
# ID: 285, Source: reclor, Questions: 1, Content length: 420 chars
# ID: 286, Source: reclor, Questions: 1, Content length: 428 chars
# ID: 287, Source: reclor, Questions: 1, Content length: 571 chars
# ID: 288, Source: reclor, Questions: 1, Content length: 425 chars
# ID: 289, Source: reclor, Questions: 1, Content length: 482 chars
# ID: 290, Source: reclor, Questions: 1, Content length: 340 chars
# ID: 291, Source: reclor, Questions: 1, Content length: 294 chars
# ID: 292, Source: reclor, Questions: 1, Content length: 679 chars
# ID: 293, Source: reclor, Questions: 1, Content length: 479 chars
# ID: 294, Source: reclor, Questions: 1, Content length: 439 chars
# ID: 295, Source: reclor, Questions: 1, Content length: 529 chars
# ID: 296, Source: reclor, Questions: 1, Content length: 145 chars
# ID: 297, Source: reclor, Questions: 1, Content length: 438 chars
# ID: 298, Source: reclor, Questions: 1, Content length: 234 chars
# ID: 299, Source: reclor, Questions: 1, Content length: 363 chars
# ID: 300, Source: reclor, Questions: 1, Content length: 373 chars

# %%
# Save results to JSON file
import json

output_path = './datasets/unified/data.json'
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)

print(f"Saved {len(all_results)} samples to {output_path}")
# Out:
# Saved 300 samples to ./datasets/unified/data.json
