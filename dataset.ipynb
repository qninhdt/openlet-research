# %%
import pandas as pd

race_h_df = pd.read_parquet('./datasets/race-h/test-00000-of-00001.parquet')
race_m_df = pd.read_parquet('./datasets/race-m/test-00000-of-00001.parquet')

# %%
race_h_df.head()
# Out:
#       example_id                                            article answer  \
# 0  high19432.txt  The rain had continued for a week and the floo...      C
# 1  high19432.txt  The rain had continued for a week and the floo...      D
# 2  high19432.txt  The rain had continued for a week and the floo...      A
# 3   high6268.txt  There is probably no field of human activity i...      B
# 4   high6268.txt  There is probably no field of human activity i...      B
#
#                                             question  \
# 0     What did Nancy try to do before she fell over?
# 1  The following are true according to the passag...
# 2  What did the local people do to help those in ...
# 3                   The passage tells us that   _  .
# 4   Traditionally,people usually thought that   _  .
#
#                                              options
# 0  [Measure the depth of the river, Look for a fa...
# 1  [It took Lizzie and Nancy about 20 minutes to ...
# 2  [They put up shelter for them in a school., Th...
# 3  [our values and lifestyles are in no field of ...
# 4  [men cared very much for clothes, women were c...

# %%
race_m_df.head()
# Out:
#        example_id                                            article answer  \
# 0  middle2177.txt  It is well-known that the "prom", a formal dan...      B
# 1  middle2177.txt  It is well-known that the "prom", a formal dan...      A
# 2  middle2177.txt  It is well-known that the "prom", a formal dan...      D
# 3  middle6088.txt  Kites have a long history. They may date back ...      B
# 4  middle6088.txt  Kites have a long history. They may date back ...      C
#
#                                             question  \
# 0    In which country is the prom called a "formal"?
# 1  Why is the prom important in the students' lives?
# 2                  What is the passage mainly about?
# 3                The first kite was born when   _  .
# 4  Kites are made of the following materials EXCE...
#
#                                              options
# 0          [America., Canada., Britain., Australia.]
# 1  [It's the sign of becoming an adult., It's an ...
# 2  [The history of the prom., The traditions of t...
# 3  [kites were used for sailing, a Chinese farmer...
# 4                       [silk, bamboo, cloth, paper]

# %%
import random

# Set seed for reproducibility (not needed anymore but keeping for consistency)
random.seed(42)

# Number of samples to select from each dataset
N = 100  # You can change this value

def select_samples_by_question_count(df, source_name, n_samples):
    """
    Select n_samples with the most questions from the dataframe
    """
    # Count questions per example_id
    question_counts = df.groupby('example_id').size().reset_index(name='question_count')
    
    # Sort by question count (descending) and get top n
    top_examples = question_counts.nlargest(n_samples, 'question_count')
    selected_ids = top_examples['example_id'].tolist()
    
    return df[df['example_id'].isin(selected_ids)], selected_ids

# Select samples from both datasets
race_h_samples, race_h_ids = select_samples_by_question_count(race_h_df, 'race-h', N)
race_m_samples, race_m_ids = select_samples_by_question_count(race_m_df, 'race-m', N)

print(f"Selected {len(race_h_ids)} unique articles from RACE-H (with most questions)")
print(f"Selected {len(race_m_ids)} unique articles from RACE-M (with most questions)")
# Out:
# Selected 100 unique articles from RACE-H (with most questions)
# Selected 100 unique articles from RACE-M (with most questions)

# %%
def transform_to_format(df, source_name, start_id=1):
    """
    Transform dataframe to the desired format, grouping by example_id
    Convert ABCD to 0123 in correct field
    """
    results = []
    current_id = start_id
    
    # Mapping for converting ABCD to 0123
    answer_map = {'A': 0, 'B': 1, 'C': 2, 'D': 3}
    
    # Group by example_id
    grouped = df.groupby('example_id')
    
    for example_id, group in grouped:
        # Get the article content (same for all rows in group)
        content = group.iloc[0]['article']
        
        # Create questions list
        questions = []
        for _, row in group.iterrows():
            questions.append({
                'content': row['question'],
                'correct': answer_map.get(row['answer'], row['answer']),  # Convert ABCD to 0123
                'options': row['options'].tolist() if hasattr(row['options'], 'tolist') else list(row['options'])
            })
        
        # Create the result object
        result = {
            'id': current_id,
            'source': source_name,
            'content': content,
            'questions': questions
        }
        
        results.append(result)
        current_id += 1
    
    return results, current_id

# Transform both datasets
race_h_results, next_id = transform_to_format(race_h_samples, 'race-h', start_id=1)
race_m_results, _ = transform_to_format(race_m_samples, 'race-m', start_id=next_id)

# Combine all results
all_results = race_h_results + race_m_results

print(f"Total samples: {len(all_results)}")
print(f"RACE-H samples: {len(race_h_results)}")
print(f"RACE-M samples: {len(race_m_results)}")
# Out:
# Total samples: 200
# RACE-H samples: 100
# RACE-M samples: 100

# %%
# Display a sample to verify the format
import json

print("Sample output:")
print(json.dumps(all_results[0], indent=2, ensure_ascii=False))
# Out:
# Sample output:
# {
#   "id": 1,
#   "source": "race-h",
#   "content": "Studies show that you may be lied to every day anywhere from 10 to 200 times. We say, \"Nice song.\" \"Honey, you don't look fat in that, no.\" But another study showed that strangers lied three times within the first 10 minutes of meeting each other. We lie more to strangers than we lie to coworkers. Men lie eight times more about themselves than they do other people. Women lie more to protect other people. If you're married, you're going to lie to your wife/ husband in one out of every 10 communications. If you're unmarried, that number drops to three. But look, if at some point you got lied to, it's because you agreed to get lied to. Truth about lying: lying's a cooperative act. Not all lies are harmful. Sometimes we're willing to lie for the sake of social dignity  , maybe to keep a private secret.\nLying is complex. It's woven into the fabric of our daily and business lives. We're deeply disturbed by the truth. We explain it, sometimes for very good reasons, other times just because we don't understand the gaps between ideals and realities in our lives. We're against lying, but secretly we're for it in ways that our society has practiced for centuries and centuries. It's as old as breathing. It's part of our culture and history. Think the stories from Dante, Shakespeare, the Bible, News of the World.\nLying has great value to the evolution of human being. Researchers have long known that the more intelligent the species, the more likely it is to lie. We human like to become leaders. It starts really early. How early? Well, babies will pretend to cry, pause, wait to see who's coming and then go right back to crying. One-year-olds learn hiding truth. Two-year-olds bluff  . Five-year-olds lie outright and try to control via flattery  . Nine-year-olds, masters of covering up. By the time you enter college, you're going to lie to your mom in one out of every five interactions. By the time we enter this work world to be breadwinners, we've entered a world that is just full of fake digital friends, business media, identity thieves, world-class cheats, ----in short, a post-truth society.\nWhat do you do? Well there are steps we can take to guide our way through the bushes. Trained lie spotters get to the truth 90% of the time. The rest of us, we're only 54% accurate. Why is it so easy to learn? There are clever liars and stupid liars. There're no real original liars. We all make the same mistakes. We all use the same techniques.",
#   "questions": [
#     {
#       "content": "From Para.1 we learn that lying is very   _  .",
#       "correct": 3,
#       "options": [
#         "harmful",
#         "easy",
#         "interesting",
#         "common"
#       ]
#     },
#     {
#       "content": "According to the passage, a lie works when   _  .",
#       "correct": 2,
#       "options": [
#         "the liar's words are sweet enough",
#         "it is given to a complete stranger",
#         "someone gives the liar cooperation",
#         "we are willing to lie for the dignity"
#       ]
#     },
#     {
#       "content": "Lying is complex because   _  .",
#       "correct": 1,
#       "options": [
#         "it is practiced by clever ones",
#         "people are for it as well as against it",
#         "ancient stories are full of lies",
#         "it is the whole part of great culture"
#       ]
#     },
#     {
#       "content": "The examples of kids lying in the passage show   _  .",
#       "correct": 0,
#       "options": [
#         "lying is a sign of intelligent development",
#         "lying is good for children's growing up",
#         "at what age children begin to tell lies",
#         "9-year-old children are masters of lying"
#       ]
#     },
#     {
#       "content": "What will the writer most likely talk about if he continues the passage?",
#       "correct": 3,
#       "options": [
#         "How to become clever liars.",
#         "How to avoid stupid lies.",
#         "How to get through the bushes.",
#         "How to tell truth from lies."
#       ]
#     }
#   ]
# }

# %%
# Summary statistics
print("\n=== Summary Statistics ===")
for result in all_results:
    print(f"ID: {result['id']}, Source: {result['source']}, Questions: {len(result['questions'])}, Content length: {len(result['content'])} chars")
# Out:
# === Summary Statistics ===
# ID: 1, Source: race-h, Questions: 5, Content length: 2462 chars
# ID: 2, Source: race-h, Questions: 6, Content length: 3408 chars
# ID: 3, Source: race-h, Questions: 5, Content length: 1168 chars
# ID: 4, Source: race-h, Questions: 6, Content length: 4244 chars
# ID: 5, Source: race-h, Questions: 5, Content length: 1664 chars
# ID: 6, Source: race-h, Questions: 5, Content length: 2101 chars
# ID: 7, Source: race-h, Questions: 5, Content length: 1696 chars
# ID: 8, Source: race-h, Questions: 5, Content length: 1548 chars
# ID: 9, Source: race-h, Questions: 5, Content length: 1656 chars
# ID: 10, Source: race-h, Questions: 5, Content length: 1490 chars
# ID: 11, Source: race-h, Questions: 5, Content length: 4164 chars
# ID: 12, Source: race-h, Questions: 5, Content length: 1052 chars
# ID: 13, Source: race-h, Questions: 5, Content length: 2375 chars
# ID: 14, Source: race-h, Questions: 5, Content length: 2140 chars
# ID: 15, Source: race-h, Questions: 5, Content length: 1468 chars
# ID: 16, Source: race-h, Questions: 5, Content length: 2392 chars
# ID: 17, Source: race-h, Questions: 5, Content length: 1440 chars
# ID: 18, Source: race-h, Questions: 5, Content length: 1158 chars
# ID: 19, Source: race-h, Questions: 5, Content length: 1862 chars
# ID: 20, Source: race-h, Questions: 6, Content length: 3611 chars
# ID: 21, Source: race-h, Questions: 5, Content length: 1140 chars
# ID: 22, Source: race-h, Questions: 5, Content length: 1765 chars
# ID: 23, Source: race-h, Questions: 5, Content length: 1228 chars
# ID: 24, Source: race-h, Questions: 5, Content length: 712 chars
# ID: 25, Source: race-h, Questions: 5, Content length: 1796 chars
# ID: 26, Source: race-h, Questions: 5, Content length: 1501 chars
# ID: 27, Source: race-h, Questions: 5, Content length: 2979 chars
# ID: 28, Source: race-h, Questions: 5, Content length: 1287 chars
# ID: 29, Source: race-h, Questions: 5, Content length: 2162 chars
# ID: 30, Source: race-h, Questions: 5, Content length: 1614 chars
# ID: 31, Source: race-h, Questions: 5, Content length: 2216 chars
# ID: 32, Source: race-h, Questions: 5, Content length: 2371 chars
# ID: 33, Source: race-h, Questions: 5, Content length: 1358 chars
# ID: 34, Source: race-h, Questions: 5, Content length: 672 chars
# ID: 35, Source: race-h, Questions: 5, Content length: 1537 chars
# ID: 36, Source: race-h, Questions: 5, Content length: 1574 chars
# ID: 37, Source: race-h, Questions: 5, Content length: 1311 chars
# ID: 38, Source: race-h, Questions: 5, Content length: 2041 chars
# ID: 39, Source: race-h, Questions: 5, Content length: 1697 chars
# ID: 40, Source: race-h, Questions: 5, Content length: 1108 chars
# ID: 41, Source: race-h, Questions: 5, Content length: 1785 chars
# ID: 42, Source: race-h, Questions: 5, Content length: 1712 chars
# ID: 43, Source: race-h, Questions: 5, Content length: 2047 chars
# ID: 44, Source: race-h, Questions: 5, Content length: 1921 chars
# ID: 45, Source: race-h, Questions: 5, Content length: 1913 chars
# ID: 46, Source: race-h, Questions: 5, Content length: 3294 chars
# ID: 47, Source: race-h, Questions: 5, Content length: 1370 chars
# ID: 48, Source: race-h, Questions: 5, Content length: 918 chars
# ID: 49, Source: race-h, Questions: 5, Content length: 3392 chars
# ID: 50, Source: race-h, Questions: 5, Content length: 2184 chars
# ID: 51, Source: race-h, Questions: 5, Content length: 2447 chars
# ID: 52, Source: race-h, Questions: 5, Content length: 1045 chars
# ID: 53, Source: race-h, Questions: 5, Content length: 917 chars
# ID: 54, Source: race-h, Questions: 5, Content length: 768 chars
# ID: 55, Source: race-h, Questions: 5, Content length: 2523 chars
# ID: 56, Source: race-h, Questions: 5, Content length: 2127 chars
# ID: 57, Source: race-h, Questions: 5, Content length: 1171 chars
# ID: 58, Source: race-h, Questions: 5, Content length: 1769 chars
# ID: 59, Source: race-h, Questions: 5, Content length: 1566 chars
# ID: 60, Source: race-h, Questions: 5, Content length: 1420 chars
# ID: 61, Source: race-h, Questions: 5, Content length: 2331 chars
# ID: 62, Source: race-h, Questions: 5, Content length: 2032 chars
# ID: 63, Source: race-h, Questions: 5, Content length: 1681 chars
# ID: 64, Source: race-h, Questions: 5, Content length: 1782 chars
# ID: 65, Source: race-h, Questions: 5, Content length: 1184 chars
# ID: 66, Source: race-h, Questions: 5, Content length: 1319 chars
# ID: 67, Source: race-h, Questions: 5, Content length: 2157 chars
# ID: 68, Source: race-h, Questions: 5, Content length: 1075 chars
# ID: 69, Source: race-h, Questions: 5, Content length: 1584 chars
# ID: 70, Source: race-h, Questions: 5, Content length: 1329 chars
# ID: 71, Source: race-h, Questions: 5, Content length: 1631 chars
# ID: 72, Source: race-h, Questions: 5, Content length: 1752 chars
# ID: 73, Source: race-h, Questions: 5, Content length: 1374 chars
# ID: 74, Source: race-h, Questions: 5, Content length: 1533 chars
# ID: 75, Source: race-h, Questions: 5, Content length: 4496 chars
# ID: 76, Source: race-h, Questions: 5, Content length: 2201 chars
# ID: 77, Source: race-h, Questions: 5, Content length: 1686 chars
# ID: 78, Source: race-h, Questions: 5, Content length: 1564 chars
# ID: 79, Source: race-h, Questions: 5, Content length: 1740 chars
# ID: 80, Source: race-h, Questions: 6, Content length: 3684 chars
# ID: 81, Source: race-h, Questions: 5, Content length: 1914 chars
# ID: 82, Source: race-h, Questions: 5, Content length: 4192 chars
# ID: 83, Source: race-h, Questions: 5, Content length: 1962 chars
# ID: 84, Source: race-h, Questions: 5, Content length: 1812 chars
# ID: 85, Source: race-h, Questions: 5, Content length: 950 chars
# ID: 86, Source: race-h, Questions: 5, Content length: 1630 chars
# ID: 87, Source: race-h, Questions: 5, Content length: 1540 chars
# ID: 88, Source: race-h, Questions: 5, Content length: 849 chars
# ID: 89, Source: race-h, Questions: 5, Content length: 1927 chars
# ID: 90, Source: race-h, Questions: 5, Content length: 2123 chars
# ID: 91, Source: race-h, Questions: 5, Content length: 1450 chars
# ID: 92, Source: race-h, Questions: 5, Content length: 2234 chars
# ID: 93, Source: race-h, Questions: 5, Content length: 1630 chars
# ID: 94, Source: race-h, Questions: 5, Content length: 2121 chars
# ID: 95, Source: race-h, Questions: 5, Content length: 2040 chars
# ID: 96, Source: race-h, Questions: 5, Content length: 735 chars
# ID: 97, Source: race-h, Questions: 5, Content length: 1265 chars
# ID: 98, Source: race-h, Questions: 5, Content length: 2211 chars
# ID: 99, Source: race-h, Questions: 5, Content length: 1245 chars
# ID: 100, Source: race-h, Questions: 5, Content length: 1543 chars
# ID: 101, Source: race-m, Questions: 5, Content length: 1437 chars
# ID: 102, Source: race-m, Questions: 5, Content length: 702 chars
# ID: 103, Source: race-m, Questions: 5, Content length: 1325 chars
# ID: 104, Source: race-m, Questions: 5, Content length: 1085 chars
# ID: 105, Source: race-m, Questions: 5, Content length: 1106 chars
# ID: 106, Source: race-m, Questions: 5, Content length: 505 chars
# ID: 107, Source: race-m, Questions: 5, Content length: 1283 chars
# ID: 108, Source: race-m, Questions: 5, Content length: 1506 chars
# ID: 109, Source: race-m, Questions: 5, Content length: 1029 chars
# ID: 110, Source: race-m, Questions: 5, Content length: 1625 chars
# ID: 111, Source: race-m, Questions: 5, Content length: 576 chars
# ID: 112, Source: race-m, Questions: 5, Content length: 1267 chars
# ID: 113, Source: race-m, Questions: 5, Content length: 1888 chars
# ID: 114, Source: race-m, Questions: 5, Content length: 1284 chars
# ID: 115, Source: race-m, Questions: 5, Content length: 710 chars
# ID: 116, Source: race-m, Questions: 5, Content length: 1139 chars
# ID: 117, Source: race-m, Questions: 5, Content length: 644 chars
# ID: 118, Source: race-m, Questions: 5, Content length: 681 chars
# ID: 119, Source: race-m, Questions: 5, Content length: 968 chars
# ID: 120, Source: race-m, Questions: 5, Content length: 1340 chars
# ID: 121, Source: race-m, Questions: 5, Content length: 346 chars
# ID: 122, Source: race-m, Questions: 5, Content length: 823 chars
# ID: 123, Source: race-m, Questions: 5, Content length: 1669 chars
# ID: 124, Source: race-m, Questions: 5, Content length: 727 chars
# ID: 125, Source: race-m, Questions: 5, Content length: 1011 chars
# ID: 126, Source: race-m, Questions: 5, Content length: 831 chars
# ID: 127, Source: race-m, Questions: 5, Content length: 1144 chars
# ID: 128, Source: race-m, Questions: 5, Content length: 698 chars
# ID: 129, Source: race-m, Questions: 5, Content length: 1101 chars
# ID: 130, Source: race-m, Questions: 5, Content length: 531 chars
# ID: 131, Source: race-m, Questions: 5, Content length: 1192 chars
# ID: 132, Source: race-m, Questions: 5, Content length: 717 chars
# ID: 133, Source: race-m, Questions: 5, Content length: 1569 chars
# ID: 134, Source: race-m, Questions: 5, Content length: 883 chars
# ID: 135, Source: race-m, Questions: 5, Content length: 594 chars
# ID: 136, Source: race-m, Questions: 5, Content length: 1505 chars
# ID: 137, Source: race-m, Questions: 5, Content length: 646 chars
# ID: 138, Source: race-m, Questions: 5, Content length: 710 chars
# ID: 139, Source: race-m, Questions: 5, Content length: 727 chars
# ID: 140, Source: race-m, Questions: 5, Content length: 605 chars
# ID: 141, Source: race-m, Questions: 5, Content length: 769 chars
# ID: 142, Source: race-m, Questions: 5, Content length: 1426 chars
# ID: 143, Source: race-m, Questions: 5, Content length: 1144 chars
# ID: 144, Source: race-m, Questions: 5, Content length: 1337 chars
# ID: 145, Source: race-m, Questions: 5, Content length: 657 chars
# ID: 146, Source: race-m, Questions: 5, Content length: 840 chars
# ID: 147, Source: race-m, Questions: 5, Content length: 665 chars
# ID: 148, Source: race-m, Questions: 5, Content length: 937 chars
# ID: 149, Source: race-m, Questions: 5, Content length: 1709 chars
# ID: 150, Source: race-m, Questions: 5, Content length: 1379 chars
# ID: 151, Source: race-m, Questions: 5, Content length: 975 chars
# ID: 152, Source: race-m, Questions: 5, Content length: 1191 chars
# ID: 153, Source: race-m, Questions: 5, Content length: 461 chars
# ID: 154, Source: race-m, Questions: 5, Content length: 485 chars
# ID: 155, Source: race-m, Questions: 5, Content length: 1095 chars
# ID: 156, Source: race-m, Questions: 5, Content length: 587 chars
# ID: 157, Source: race-m, Questions: 5, Content length: 441 chars
# ID: 158, Source: race-m, Questions: 5, Content length: 357 chars
# ID: 159, Source: race-m, Questions: 5, Content length: 963 chars
# ID: 160, Source: race-m, Questions: 5, Content length: 1390 chars
# ID: 161, Source: race-m, Questions: 5, Content length: 1539 chars
# ID: 162, Source: race-m, Questions: 5, Content length: 1158 chars
# ID: 163, Source: race-m, Questions: 5, Content length: 822 chars
# ID: 164, Source: race-m, Questions: 5, Content length: 1176 chars
# ID: 165, Source: race-m, Questions: 5, Content length: 667 chars
# ID: 166, Source: race-m, Questions: 5, Content length: 955 chars
# ID: 167, Source: race-m, Questions: 5, Content length: 726 chars
# ID: 168, Source: race-m, Questions: 5, Content length: 1166 chars
# ID: 169, Source: race-m, Questions: 5, Content length: 731 chars
# ID: 170, Source: race-m, Questions: 5, Content length: 1438 chars
# ID: 171, Source: race-m, Questions: 5, Content length: 490 chars
# ID: 172, Source: race-m, Questions: 5, Content length: 1269 chars
# ID: 173, Source: race-m, Questions: 5, Content length: 460 chars
# ID: 174, Source: race-m, Questions: 5, Content length: 1105 chars
# ID: 175, Source: race-m, Questions: 5, Content length: 350 chars
# ID: 176, Source: race-m, Questions: 5, Content length: 1373 chars
# ID: 177, Source: race-m, Questions: 5, Content length: 1347 chars
# ID: 178, Source: race-m, Questions: 5, Content length: 661 chars
# ID: 179, Source: race-m, Questions: 5, Content length: 1466 chars
# ID: 180, Source: race-m, Questions: 5, Content length: 944 chars
# ID: 181, Source: race-m, Questions: 5, Content length: 1348 chars
# ID: 182, Source: race-m, Questions: 5, Content length: 1069 chars
# ID: 183, Source: race-m, Questions: 5, Content length: 679 chars
# ID: 184, Source: race-m, Questions: 5, Content length: 846 chars
# ID: 185, Source: race-m, Questions: 5, Content length: 806 chars
# ID: 186, Source: race-m, Questions: 5, Content length: 1033 chars
# ID: 187, Source: race-m, Questions: 5, Content length: 344 chars
# ID: 188, Source: race-m, Questions: 5, Content length: 1152 chars
# ID: 189, Source: race-m, Questions: 5, Content length: 805 chars
# ID: 190, Source: race-m, Questions: 5, Content length: 693 chars
# ID: 191, Source: race-m, Questions: 5, Content length: 477 chars
# ID: 192, Source: race-m, Questions: 5, Content length: 310 chars
# ID: 193, Source: race-m, Questions: 5, Content length: 977 chars
# ID: 194, Source: race-m, Questions: 5, Content length: 1047 chars
# ID: 195, Source: race-m, Questions: 5, Content length: 375 chars
# ID: 196, Source: race-m, Questions: 5, Content length: 639 chars
# ID: 197, Source: race-m, Questions: 5, Content length: 256 chars
# ID: 198, Source: race-m, Questions: 5, Content length: 927 chars
# ID: 199, Source: race-m, Questions: 5, Content length: 1073 chars
# ID: 200, Source: race-m, Questions: 6, Content length: 1472 chars

# %%
# Save results to JSON file
import json

output_path = './datasets/unified/data.json'
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)

print(f"Saved {len(all_results)} samples to {output_path}")
# Out:
# Saved 200 samples to ./datasets/unified/data.json
